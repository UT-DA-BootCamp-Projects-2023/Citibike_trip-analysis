# %% [markdown]
# ## Dependencies and Setup

# %%
# import required libiraries/packages

import pandas as pd
from pathlib import Path

# %%
# define citbike data file name list
citibikefilelist = ['JC-202206-citibike-tripdata.csv',
                'JC-202207-citbike-tripdata.csv', 
                'JC-202208-citibike-tripdata.csv',
                'JC-202209-citibike-tripdata.csv',
                'JC-202210-citibike-tripdata.csv',
                'JC-202211-citibike-tripdata.csv',
                'JC-202212-citibike-tripdata.csv',
                'JC-202301-citibike-tripdata.csv',
                'JC-202302-citibike-tripdata.csv',
                'JC-202303-citibike-tripdata.csv',
                'JC-202304-citibike-tripdata.csv',
                'JC-202305-citibike-tripdata.csv']
# Create Empty DataFrame with Column Header
citibike_jun22_to_may23_df = pd.DataFrame(columns=['ride_id', 'rideable_type', 'started_at', 'ended_at','start_station_name',
                                                   'start_station_id','end_station_name','end_station_id','start_lat','start_lng',
                                                   'end_lat','end_lng','member_casual'])

# Import citibike-tripdata 
for eachfileName in citibikefilelist:
    filepath = Path(eachfileName)
    tempDF = pd.read_csv(filepath,encoding="utf-8")

    citibike_jun22_to_may23_df = pd.concat([citibike_jun22_to_may23_df,tempDF],ignore_index=True)


# Display dataframe
citibike_jun22_to_may23_df
# Out:
#                  ride_id  rideable_type           started_at  \
# 0       EEA3CD3B084370F4   classic_bike  2022-06-30 19:17:16
# 1       BF568C9B3C5FAE94   classic_bike  2022-06-02 12:46:44
# 2       DF6B06D460481A7E   classic_bike  2022-06-05 14:17:34
# 3       A26CDB92CDF7E0EE  electric_bike  2022-06-01 18:57:12
# 4       A2A50E81031E9E7F  electric_bike  2022-06-14 22:45:53
# ...                  ...            ...                  ...
# 989176  9549398286BB59B5    docked_bike  2023-05-27 13:24:51
# 989177  AB0790683044D89E   classic_bike  2023-05-18 17:12:07
# 989178  68226FA538A405CA   classic_bike  2023-05-05 18:44:57
# 989179  CABAC21C0F0140A5   classic_bike  2023-05-16 11:56:11
# 989180  4AABD797EF6F7BB2   classic_bike  2023-05-30 11:04:46
#
#                    ended_at                            start_station_name  \
# 0       2022-06-30 19:27:13                        Clinton St & Newark St
# 1       2022-06-02 15:08:33                        Clinton St & Newark St
# ...

# %%
# Remove unwanted column name 'A'
citibike_jun22_to_may23_df = citibike_jun22_to_may23_df.drop(['start_station_id','end_station_id'], axis=1)

# %%
#  Check for null values in the dataframe under an entire DataFrame:
citibike_jun22_to_may23_df.loc[citibike_jun22_to_may23_df.isna().any(axis=1)]
# Out:
#                  ride_id  rideable_type           started_at  \
# 552     516ECE3F2AF9F64D   classic_bike  2022-06-28 23:18:34
# 7845    795A8C597B153224   classic_bike  2022-06-25 09:18:42
# 7846    3094EA636FBBC9D3  electric_bike  2022-06-14 19:28:22
# 7847    C9DB0C52B27CBE19   classic_bike  2022-06-30 11:29:14
# 7848    9CE20E8E596EAC44  electric_bike  2022-06-22 20:48:02
# ...                  ...            ...                  ...
# 942108  273B1705779A2A7B   classic_bike  2023-05-09 15:39:04
# 946968  8D7D10D23235B144   classic_bike  2023-05-27 14:29:55
# 946971  27BC7AD9933BB552   classic_bike  2023-05-29 16:05:44
# 946973  EE963FD1CFE05298   classic_bike  2023-05-11 17:46:20
# 946976  BB08E784171FFFA5  electric_bike  2023-05-07 09:27:36
#
#                    ended_at                        start_station_name  \
# 552     2022-06-30 00:18:29                             Washington St
# 7845    2022-06-26 10:18:22                          7 St & Monroe St
# ...

# %%
# remove null value data
citibike_jun22_to_may23_df = citibike_jun22_to_may23_df.dropna().reset_index(drop=True)
citibike_jun22_to_may23_df
# Out:
#                  ride_id  rideable_type           started_at  \
# 0       EEA3CD3B084370F4   classic_bike  2022-06-30 19:17:16
# 1       BF568C9B3C5FAE94   classic_bike  2022-06-02 12:46:44
# 2       DF6B06D460481A7E   classic_bike  2022-06-05 14:17:34
# 3       A26CDB92CDF7E0EE  electric_bike  2022-06-01 18:57:12
# 4       A2A50E81031E9E7F  electric_bike  2022-06-14 22:45:53
# ...                  ...            ...                  ...
# 985858  9549398286BB59B5    docked_bike  2023-05-27 13:24:51
# 985859  AB0790683044D89E   classic_bike  2023-05-18 17:12:07
# 985860  68226FA538A405CA   classic_bike  2023-05-05 18:44:57
# 985861  CABAC21C0F0140A5   classic_bike  2023-05-16 11:56:11
# 985862  4AABD797EF6F7BB2   classic_bike  2023-05-30 11:04:46
#
#                    ended_at                            start_station_name  \
# 0       2022-06-30 19:27:13                        Clinton St & Newark St
# 1       2022-06-02 15:08:33                        Clinton St & Newark St
# ...

# %%
# Check if ride ID column as unique values
citibike_jun22_to_may23_df['ride_id'].is_unique
# Out:
# True

# %%
# Export the data to CSV
citibike_jun22_to_may23_df.to_csv("citibike_jun22_to_may23_df.csv",index=False)
